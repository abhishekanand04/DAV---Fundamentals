# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/DAV---Fundamentals/blob/fundamentals/Dec24_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC -O weight-height.csv
# Out:
# --2025-01-13 16:03:15--  https://drive.google.com/uc?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# Resolving drive.google.com (drive.google.com)... 172.217.164.14, 2607:f8b0:4025:815::200e
# Connecting to drive.google.com (drive.google.com)|172.217.164.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC [following]
# --2025-01-13 16:03:15--  https://drive.usercontent.google.com/download?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.12.1, 2607:f8b0:4025:815::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.12.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 428120 (418K) [application/octet-stream]
# Saving to: ‘weight-height.csv’
#
# weight-height.csv   100%[===================>] 418.09K  --.-KB/s    in 0.07s
#
# 2025-01-13 16:03:17 (5.80 MB/s) - ‘weight-height.csv’ saved [428120/428120]

# %%
df_hw = pd.read_csv("weight-height.csv")

df_hw.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
sns.scatterplot(x=df_hw["Height"], y=df_hw["Weight"])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
df_hw[["Height", "Weight"]].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
# The Pearson correlation coefficient is 0.924 => strong +ve correlation.

# %%
from scipy.stats import pearsonr, spearmanr

# %%
# Taking the above Rank(Experience) as x and Rank(Salary) as y

x = [1, 3, 4, 5, 2]
y = [1, 2, 5, 4, 3]

# calculate Spearman's correlation coefficient and p-value
corr, pval = spearmanr(x, y)

# print the result
print("Spearman's correlation coefficient:", corr)
# Out:
# Spearman's correlation coefficient: 0.7999999999999999

# %%
pval
# Out:
# 0.10408803866182788

# %%
# H0: No correlation
# Ha: There is correlation

alpha = 0.05

if pval < alpha:
  print("Reject H0")
  print("There is correlation")
else:
  print("Fail to reject H0")
  print("No correlation")
# Out:
# Fail to reject H0
# No correlation

# %%
pearsonr(df_hw["Height"], df_hw["Weight"])
# Out:
# PearsonRResult(statistic=0.9247562987409148, pvalue=0.0)

# %%
spearmanr(df_hw["Height"], df_hw["Weight"])
# Out:
# SignificanceResult(statistic=0.9257076644210767, pvalue=0.0)

# %%
stat, pval = pearsonr(df_hw["Height"], df_hw["Weight"])

alpha = 0.05

if pval < alpha:
  print("Reject H0")
  print("There is correlation")
else:
  print("Fail to reject H0")
  print("No correlation")
# Out:
# Reject H0
# There is correlation

# %%
stat, pval = spearmanr(df_hw["Height"], df_hw["Weight"])

alpha = 0.05

if pval < alpha:
  print("Reject H0")
  print("There is correlation")
else:
  print("Fail to reject H0")
  print("No correlation")
# Out:
# Reject H0
# There is correlation

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

# calculate Spearman's correlation coefficient and p-value
corr, pval = spearmanr(x, y)

# print the result
print("Spearman's correlation coefficient:", corr)
# Out:
# Spearman's correlation coefficient: -0.9999999999999999

# %%
pval
# Out:
# 1.4042654220543672e-24

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]

# calculate Spearman's correlation coefficient and p-value
corr, pval = pearsonr(x, y)

# print the result
print("Spearman's correlation coefficient:", corr)
# Out:
# Spearman's correlation coefficient: -0.8285038835884277

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]

# calculate Spearman's correlation coefficient and p-value
corr, pval = spearmanr(x, y)

# print the result
print("Spearman's correlation coefficient:", corr)
# Out:
# Spearman's correlation coefficient: -0.7857142857142859

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25 -O concrete_data.csv
# Out:
# --2025-01-13 17:40:05--  https://drive.google.com/uc?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25
# Resolving drive.google.com (drive.google.com)... 172.217.0.78, 2607:f8b0:4025:815::200e
# Connecting to drive.google.com (drive.google.com)|172.217.0.78|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25 [following]
# --2025-01-13 17:40:05--  https://drive.usercontent.google.com/download?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.12.1, 2607:f8b0:4025:815::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.12.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59010 (58K) [application/octet-stream]
# Saving to: ‘concrete_data.csv’
#
# concrete_data.csv   100%[===================>]  57.63K  --.-KB/s    in 0.02s
#
# 2025-01-13 17:40:08 (2.54 MB/s) - ‘concrete_data.csv’ saved [59010/59010]

# %%
import pandas as pd
df = pd.read_csv('concrete_data.csv')
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.0)
plt.figure(figsize=(8,6))
correlation_values = df.corr(method = 'pearson')
sns.heatmap(correlation_values, vmax = .6, linewidths=0.01, square=True, annot=True, cmap="RdBu", linecolor="black")
plt.title('Correlation between features');
